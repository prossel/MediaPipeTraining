# %% [markdown]
# Display shell python version

# %%
# !python --version

# %% [markdown]
# Display python version from phython code

# %%
import sys
print(f"Python version: {sys.version}")

# %%
# Display venv info
print(f"Venv: {sys.prefix}")
